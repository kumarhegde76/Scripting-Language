# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
d=pd.read_csv("StudentsPerformance.csv")

# %%
d
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                         NaN      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                         NaN      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                         NaN      standard
# 7      male        group B                         NaN  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
d.drop(["lunch", "test preparation course"], axis=1,inplace = True)

# %%
d
# Out:
#      gender race/ethnicity parental level of education  mathscore  \
# 0    female        group B           bachelor's degree         72
# 1    female        group C                         NaN         69
# 2    female        group B             master's degree         90
# 3      male        group A          associate's degree         47
# 4      male        group C                         NaN         76
# 5    female        group B          associate's degree         71
# 6    female        group B                         NaN         88
# 7      male        group B                         NaN         40
# 8      male        group D                 high school         64
# 9    female        group B                 high school         38
# 10     male        group C          associate's degree         58
# 11     male        group D          associate's degree         40
# 12   female        group B                 high school         65
# ...

# %%
d
# Out:
#      gender race/ethnicity parental level of education  mathscore  \
# 0    female        group B           bachelor's degree         72
# 1    female        group C                         NaN         69
# 2    female        group B             master's degree         90
# 3      male        group A          associate's degree         47
# 4      male        group C                         NaN         76
# 5    female        group B          associate's degree         71
# 6    female        group B                         NaN         88
# 7      male        group B                         NaN         40
# 8      male        group D                 high school         64
# 9    female        group B                 high school         38
# 10     male        group C          associate's degree         58
# 11     male        group D          associate's degree         40
# 12   female        group B                 high school         65
# ...

# %%
d['parental level of education'] = d['parental level of education'].fillna('null')

# %%
d
# Out:
#      gender race/ethnicity parental level of education  mathscore  \
# 0    female        group B           bachelor's degree         72
# 1    female        group C                        null         69
# 2    female        group B             master's degree         90
# 3      male        group A          associate's degree         47
# 4      male        group C                        null         76
# 5    female        group B          associate's degree         71
# 6    female        group B                        null         88
# 7      male        group B                        null         40
# 8      male        group D                 high school         64
# 9    female        group B                 high school         38
# 10     male        group C          associate's degree         58
# 11     male        group D          associate's degree         40
# 12   female        group B                 high school         65
# ...

# %%
d['race/ethnicity'] = d['race/ethnicity'].map({
    'group A':'Asian Students',
    'group B':'African Students',
    'group C':'Afro-Asian',
    'group D':'American Students',
    'group E':'Europe Students'})

# %%
d
# Out:
#      gender     race/ethnicity parental level of education  mathscore  \
# 0    female   African Students           bachelor's degree         72
# 1    female         Afro-Asian                        null         69
# 2    female   African Students             master's degree         90
# 3      male     Asian Students          associate's degree         47
# 4      male         Afro-Asian                        null         76
# 5    female   African Students          associate's degree         71
# 6    female   African Students                        null         88
# 7      male   African Students                        null         40
# 8      male  American Students                 high school         64
# 9    female   African Students                 high school         38
# 10     male         Afro-Asian          associate's degree         58
# 11     male  American Students          associate's degree         40
# ...

# %%
import seaborn as sns
df = pd.read_csv('StudentsPerformance.csv')
ax = sns.countplot(x ='gender', hue = 'parental level of education', palette = 'Set1', data = df)
ax.set(title = 'Genderwise comparison of level achieved', xlabel = 'Gender', ylabel = 'Number')
plt.show()

# %%
df['race/ethnicity']= df['race/ethnicity'].map({
   'group A':'Asian Students',
    'group B':'African Students',
    'group C':'Afro-Asian',
    'group D':'American Students',
    'group E':'Europe Students'})  

ax=sb.countplot(x='gender',hue='race/ethnicity',palette='Set1',data=d)
ax.set(title="Ethnicity of gender",xlabel='ethnicity',ylabel='Total')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67621cceb376> in <module>()
# ----> 1 df['race/ethnicity']=df['race/ethnicity'].map({
#       2    'group A':'Asian Students',
#       3     'group B':'African Students',
#       4     'group C':'Afro-Asian',
#       5     'group D':'American Students',
#
# NameError: name 'df' is not defined
